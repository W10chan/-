# %%
import pandas as pd
import seaborn as sns
from scipy.stats import spearmanr
import matplotlib.pyplot as plt

import os

# %%
#フォント設定
plt.rcParams['font.family'] = 'Times New Roman' # font familyの設定
#plt.rcParams['mathtext.fontset'] = 'stix' # math fontの設定
plt.rcParams["font.size"] = 15 # 全体のフォントサイズが変更されます。
#plt.rcParams['xtick.labelsize'] = 9 # 軸だけ変更されます。
#plt.rcParams['ytick.labelsize'] = 24 # 軸だけ変更されます


#軸設定
plt.rcParams['xtick.direction'] = 'in' #x軸の目盛りの向き
plt.rcParams['ytick.direction'] = 'in' #y軸の目盛りの向き

#軸大きさ
#plt.rcParams["xtick.major.width"] = 1.0             #x軸主目盛り線の線幅
#plt.rcParams["ytick.major.width"] = 1.0             #y軸主目盛り線の線幅
#plt.rcParams["xtick.minor.width"] = 1.0             #x軸補助目盛り線の線幅
#plt.rcParams["ytick.minor.width"] = 1.0             #y軸補助目盛り線の線幅
#plt.rcParams["xtick.major.size"] = 10               #x軸主目盛り線の長さ
#plt.rcParams["ytick.major.size"] = 10               #y軸主目盛り線の長さ
#plt.rcParams["xtick.minor.size"] = 5                #x軸補助目盛り線の長さ
#plt.rcParams["ytick.minor.size"] = 5                #y軸補助目盛り線の長さ
#plt.rcParams["axes.linewidth"] = 1.0                #囲みの太さ

#凡例設定
plt.rcParams["legend.fancybox"] = False  # 丸角OFF
plt.rcParams["legend.framealpha"] = 1  # 透明度の指定、0で塗りつぶしなし
plt.rcParams["legend.edgecolor"] = 'black'  # edgeの色を変更
plt.rcParams["legend.markerscale"] = 5 #markerサイズの倍率
# CSVファイルのパス
#csv_path = '4th_trading_trend_2023.csv'

# %%
# CSVファイルのパスを指定
input_file_path = "1st_trading_trend_2023.csv"

# CSVファイルを読み込む
df = pd.read_csv(input_file_path)

# Kp_1列とKd-Ki_1列を選択
kp_1 = df['Kp']  
kd_ki_1 = df['Total number of shares purchased']
#Med_purchase_num
#Max_purchase_num
#Total number of shares purchased
#Med stock price change rate at time of purchase
#Med_disposal_num
#Max_disposal_num
#Total number of shares sold
#Med stock price change rate at time of sale

# スピアマンの順位相関係数を計算
rho, _ = spearmanr(kp_1, kd_ki_1)

# 結果の表示
print(f"Spearmanの順位相関係数: {rho:.4f}")
# Out:
# Spearmanの順位相関係数: -0.7746

# %%
# CSVファイルのパス
csv_path = '1st_trading_trend_2023.csv'

# CSVファイルから指定の列を読み取り
columns_to_read = [
    'Kp', 'Ki', 'Kd','Med stock price change rate at time of purchase',
    'Med stock price change rate at time of sale'
]

data = pd.read_csv(csv_path, usecols=columns_to_read)

# 変数名を短くする
short_column_names = [
    'Kp', 'Ki', 'Kd','Med stock price change rate at time of purchase',
    'Med stock price change rate at time of sale'
]
data.columns = short_column_names

# スピアマンの順位相関係数を計算
correlation_matrix = data.corr(method='spearman')

# ヒートマップの作成
plt.figure(figsize=(12, 10))

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5, xticklabels=short_column_names, yticklabels=short_column_names)
#correlation_matrix: 相関係数の行列です。各変数の相関が格納されています。
#annot=True: ヒートマップの各セルに値を表示するかどうかを指定。Trueに設定すると、セルに実際の数値が表示。
#cmap='coolwarm': カラーマップの指定。こ
#fmt='.2f': セルの値の表示フォーマット。小数点以下2桁まで。
#linewidths=.5: セル間の線の太さを指。
#xticklabels=short_column_names: X軸のラベルに使用される変数名のリストを指定。
#yticklabels=short_column_names: Y軸のラベルに使用される変数名のリストを指定。

plt.title("2nd_param")
plt.tight_layout()
#plt.savefig("1st_trend_Spearman_buy_2.png")
plt.show()

# %%
import pandas as pd
import seaborn as sns
from scipy.stats import spearmanr
import matplotlib.pyplot as plt
import os
import matplotlib.pyplot as plt

# CSVファイルのパス
csv_path = '4th_trading_trend_2023.csv'
# Create a folder to save images if it doesn't exist
output_folder = 'パラメータ相関_論文用_4'

#フォント設定
plt.rcParams['font.family'] = 'Times New Roman' # font familyの設定
#plt.rcParams['mathtext.fontset'] = 'stix' # math fontの設定
plt.rcParams["font.size"] = 15 # 全体のフォントサイズが変更されます。
plt.rcParams['xtick.labelsize'] = 13 # 軸だけ変更されます。
plt.rcParams['ytick.labelsize'] = 13 # 軸だけ変更されます


#軸設定
plt.rcParams['xtick.direction'] = 'in' #x軸の目盛りの向き
plt.rcParams['ytick.direction'] = 'in' #y軸の目盛りの向き

#軸大きさ
#plt.rcParams["xtick.major.width"] = 1.0             #x軸主目盛り線の線幅
#plt.rcParams["ytick.major.width"] = 1.0             #y軸主目盛り線の線幅
#plt.rcParams["xtick.minor.width"] = 1.0             #x軸補助目盛り線の線幅
#plt.rcParams["ytick.minor.width"] = 1.0             #y軸補助目盛り線の線幅
plt.rcParams["xtick.major.size"] = 10               #x軸主目盛り線の長さ
plt.rcParams["ytick.major.size"] = 10               #y軸主目盛り線の長さ
plt.rcParams["xtick.minor.size"] = 5                #x軸補助目盛り線の長さ
plt.rcParams["ytick.minor.size"] = 5                #y軸補助目盛り線の長さ
plt.rcParams["axes.linewidth"] = 2.0                #囲みの太さ

#凡例設定
plt.rcParams["legend.fancybox"] = False  # 丸角OFF
plt.rcParams["legend.framealpha"] = 1  # 透明度の指定、0で塗りつぶしなし
plt.rcParams["legend.edgecolor"] = 'black'  # edgeの色を変更
plt.rcParams["legend.markerscale"] = 5 #markerサイズの倍率


# CSVファイルから指定の列を読み取り
columns_to_read = [
    'Kp', 'Ki', 'Kd'

]
#    'Med_purchase_num',
#    'Med_disposal_num',
#    'Max_purchase_num',
#    'Max_disposal_num',
#    'Total number of shares purchased',
#    'Total number of shares sold'

data = pd.read_csv(csv_path, usecols=columns_to_read)

# 変数名を短くする
short_column_names = [
    'Kp', 'Ki', 'Kd'

]

# ラベル名にしたい名前をリストにセット
custom_labels = [
    'Kp',
    'Ki',
    'Kd'
    
]
    #'Median of the purchased quantity of stocks (shares)',
    #'Median of the sold quantity of stocks (shares)',
    #'Maximum quantity of the purchased stocks (shares)',
    #'Maximum quantity of the sold stocks (shares)', 
    #'Total quantity of purchased stocks (shares)',
    #'Total quantity of sold stocks (shares)'
data.columns = short_column_names

os.makedirs(output_folder, exist_ok=True)
# スピアマンの順位相関係数を計算
correlation_matrix = data.corr(method='spearman')

# すべての組み合わせに対して散布図を作成
for i in range(len(short_column_names)):
    for j in range(i+1, len(short_column_names)):
        variable1 = short_column_names[i]
        variable2 = short_column_names[j]
        correlation = correlation_matrix.loc[variable1, variable2]
        
        #plt.figure(figsize=(7.5, 7.5))
        sns.scatterplot(x=data[variable1], y=data[variable2])
        #plt.title(f'ρ = {correlation:.2f}', loc='left')
        # タイトルのρをイタリック体にする
        plt.title(r'$\rho$ = {:.2f}'.format(correlation), loc='left', fontsize=24, style='italic')
        plt.xlabel(custom_labels[i])
        plt.ylabel(custom_labels[j])
        plt.tight_layout()
 # Save the figure in the output folder
        output_file_path = os.path.join(output_folder, f'scatter_plot_{variable1}_{variable2}.png')
        plt.savefig(output_file_path)
        plt.show()

 # Close the plot to prevent overlapping plots
        plt.close()
        # 散布図を表示
        #plt.show()
print(f"Scatter plots saved in the '{output_folder}' folder.")
# Out:
# Scatter plots saved in the 'パラメータ相関_論文用_4' folder.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# CSVファイルのパス
csv_path = '2nd_trading_trend_2023.csv'

# CSVファイルから指定の列を読み取り
columns_to_read = ['No', 'Kd', 'Ki']
data = pd.read_csv(csv_path, usecols=columns_to_read)

# スピアマンの順位相関係数を計算
correlation_matrix = data[['Kd', 'Ki']].corr(method='spearman')

# 散布図を作成
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Kd', y='Ki', data=data)

# 各点に番号を書き込む
for i, txt in enumerate(data['No']):
    plt.annotate(txt, (data['Kd'][i], data['Ki'][i]), textcoords="offset points", xytext=(0,5), ha='center')

plt.title('Kp vs Ki Scatter Plot with No')
plt.xlabel('Kd')
plt.ylabel('Ki')
plt.show()

# %%
# CSVファイルのパス
csv_path = '1st_trading_trend_2023.csv'

# CSVファイルから指定の列を読み取り
columns_to_read = [
    'Kp', 'Ki', 'Kd', 'Med_purchase_num', 'Total number of shares purchased',
    'Med stock price at time of purchase', 'Med stock price change rate at time of purchase','Med_disposal_num',
'Total number of shares sold','Med stock price at time of sale','Med stock price change rate at time of sale'
]

data = pd.read_csv(csv_path, usecols=columns_to_read)

# 変数名を短くする
short_column_names = [
    'Kp', 'Ki', 'Kd', 'Med_purch_num', 'Total_shares_purchased', 'Med_stock_price_purchase',
    'Med_price_change_rate_purchase','Med_disposal_num',
    'Total_shares_sold','Med_stock_price_sale', 'Med_price_change_rate_sale'
]


data.columns = short_column_names

# スピアマンの順位相関係数を計算
correlation_matrix = data.corr(method='spearman')

# '|Ki|' との相関係数のみを抽出
ki_correlation = correlation_matrix['Kp']

# 結果を表示
print(ki_correlation)
# 相関係数をCSVファイルに保存
#ki_correlation.to_csv('3rd_abs_Kd_correlation_matrix.csv')
# Out:
# Kp                                1.000000
# Ki                                0.005562
# |Kd|                              0.296107
# Med_purch_num                    -0.564445
# Total_shares_purchased           -0.774597
# Med_stock_price_purchase          0.286957
# Med_price_change_rate_purchase    0.251449
# Med_disposal_num                 -0.610355
# Total_shares_sold                -0.745269
# Med_stock_price_sale             -0.091355
# Med_price_change_rate_sale       -0.271075
# Name: Kp, dtype: float64

# %%
# CSVファイルから指定の列を読み取り
columns_to_read = [
'Kp','|Ki|','|Kd|','Med_disposal_num','Max_disposal_num',
'Total number of shares sold','Med stock price at time of sale','Med stock price change rate at time of sale'
]

data = pd.read_csv(csv_path, usecols=columns_to_read)

# 変数名を短くする
short_column_names = [
    'Kp','|Ki|','|Kd|',
    'Med_disposal_num',  'Max_disposal_num',
    'Total_shares_sold','Med_stock_price_sale', 'Med_price_change_rate_sale'
]

data.columns = short_column_names

# スピアマンの順位相関係数を計算
correlation_matrix = data.corr(method='spearman')

# ヒートマップの作成
plt.figure(figsize=(12, 10))

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5, xticklabels=short_column_names, yticklabels=short_column_names)
#correlation_matrix: 相関係数の行列です。各変数の相関が格納されています。
#annot=True: ヒートマップの各セルに値を表示するかどうかを指定。Trueに設定すると、セルに実際の数値が表示。
#cmap='coolwarm': カラーマップの指定。こ
#fmt='.2f': セルの値の表示フォーマット。小数点以下2桁まで。
#linewidths=.5: セル間の線の太さを指。
#xticklabels=short_column_names: X軸のラベルに使用される変数名のリストを指定。
#yticklabels=short_column_names: Y軸のラベルに使用される変数名のリストを指定。

plt.title("1st_trend_Spearman's(sold)")
plt.tight_layout()
plt.savefig("1st_trend_Spearman_sold_2.png")
plt.show()

# %%
# CSVファイルから指定の列を読み取り
columns_to_read = [
'Kp','Ki','Kd','Ki/|Kp|','Kd/|Kp|','Kd/|Kp|-Ki/|Kp|',
'Growth_rate_of_total_assets','positive_count' ,'negative_count',
]

data = pd.read_csv(csv_path, usecols=columns_to_read)

# 変数名を短くする
short_column_names = [
    'Kp','Ki','Kd','Ki/|Kp|','Kd/|Kp|','Kd/|Kp|-Ki/|Kp|',
     'Growth_assets',   'pos_count',  'neg_count'
]

data.columns = short_column_names

# スピアマンの順位相関係数を計算
correlation_matrix = data.corr(method='spearman')

# ヒートマップの作成
plt.figure(figsize=(12, 10))

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5, xticklabels=short_column_names, yticklabels=short_column_names)
#correlation_matrix: 相関係数の行列です。各変数の相関が格納されています。
#annot=True: ヒートマップの各セルに値を表示するかどうかを指定。Trueに設定すると、セルに実際の数値が表示。
#cmap='coolwarm': カラーマップの指定。こ
#fmt='.2f': セルの値の表示フォーマット。小数点以下2桁まで。
#linewidths=.5: セル間の線の太さを指。
#xticklabels=short_column_names: X軸のラベルに使用される変数名のリストを指定。
#yticklabels=short_column_names: Y軸のラベルに使用される変数名のリストを指定。

plt.title("4th_trend_Spearman's(other)")
plt.tight_layout()
plt.savefig("4th_trend_Spearman_other.png")
plt.show()

# %%
# CSVファイルから指定の列を読み取り
columns_to_read = [
'Med_purchase_num','Max_purchase_num','Total number of shares purchased',
'Med stock price at time of purchase','Med stock price change rate at time of purchase',
'Med_disposal_num','Max_disposal_num','Total number of shares sold','Med stock price at time of sale',
'Med stock price change rate at time of sale',
'Growth_rate_of_total_assets','positive_count' ,'negative_count'
]

data = pd.read_csv(csv_path, usecols=columns_to_read)

# 変数名を短くする
short_column_names = [
'Med_purch_num', 'Max_purch_num', 'Total_shares_purchased',
'Med_stock_price_purchase','Med_price_change_rate_purchase',
'Med_disposal_num',  'Max_disposal_num','Total_shares_sold','Med_stock_price_sale',
'Med_price_change_rate_sale',
'Growth_assets',   'pos_count',  'neg_count'
]

data.columns = short_column_names

# スピアマンの順位相関係数を計算
correlation_matrix = data.corr(method='spearman')

# ヒートマップの作成
plt.figure(figsize=(12, 10))

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5, xticklabels=short_column_names, yticklabels=short_column_names)
#correlation_matrix: 相関係数の行列です。各変数の相関が格納されています。
#annot=True: ヒートマップの各セルに値を表示するかどうかを指定。Trueに設定すると、セルに実際の数値が表示。
#cmap='coolwarm': カラーマップの指定。こ
#fmt='.2f': セルの値の表示フォーマット。小数点以下2桁まで。
#linewidths=.5: セル間の線の太さを指。
#xticklabels=short_column_names: X軸のラベルに使用される変数名のリストを指定。
#yticklabels=short_column_names: Y軸のラベルに使用される変数名のリストを指定。

plt.title("4th_trend_Spearman's(other2)")
plt.tight_layout()
plt.savefig("4th_trend_Spearman_other2.png")
plt.show()

# %%
#ピアソン
columns_to_read = [
    'Kp_4',
    'Ki_4',
    'Kd_4',
    'Ki/|Kp|_4',
    'Average number of shares purchased_4',
    'Average stock price at time of purchase_4',
    'Average stock price change rate at time of purchase_4',
    'Average stock price at time of sale_4',
    'Average stock price change rate at time of sale_4'

]
data = pd.read_csv(csv_path, usecols=columns_to_read)
# 変数名を短くする
short_column_names = [
    'Kp_4',
    'Ki_4',
    'Kd_4',
    'Ki/|Kp|_4',
    'Ave number of shares purchased_4',
    'Ave stock price at time of purchase_4',
    'Ave stock price change rate at time of purchase_4',
    'Ave stock price at time of sale_4',
    'Ave stock price change rate at time of sale_4'
]

data.columns = short_column_names

# 相関係数を計算
correlation_matrix = data.corr(method='pearson')

# 結果を新しいCSVファイルに保存
correlation_matrix.to_csv('4th_correlation_results.csv')

print("相関係数の結果が 'correlation_results.csv' に保存されました。")
# Out:
# 相関係数の結果が 'correlation_results.csv' に保存されました。

# %%
import os


# CSVファイルから指定の列を読み取り
columns_to_read = [
    'Kp_2', 'Ki_2', 'Kd_2', 'Ki/|Kp|_2', 'Kd/|Kp|_2',
    'Average number of shares purchased_2',
    'Average stock price at time of purchase_2',
    'Average stock price change rate at time of purchase_2',
    'Average number of shares sold_2',
    'Average stock price at time of sale_2',
    'Average stock price change rate at time of sale_2'
]

data = pd.read_csv(csv_path, usecols=columns_to_read)

# 変数名を短くする
short_column_names = [
    'Kp_2', 'Ki_2', 'Kd_2', 'Ki_abs-Kp_2', 'Kd_abs-Kp_2',
    'Ave_stock_purchased_2',
    'Ave_stock_price_at_purchase_2',
    'Ave_stock_price_change_at_purchase_2',
    'Ave_stock_sold_2',
    'Ave_stock_price_at_sale_2',
    'Ave_stock_price_change_at_sale_2'
]

data.columns = short_column_names

# スピアマンの順位相関係数を計算
correlation_matrix = data.corr(method='spearman')

# 相関係数が0.4以上の組み合わせを抽出
high_correlation_pairs = correlation_matrix[abs(correlation_matrix) >= 0.4].stack().reset_index()
high_correlation_pairs.columns = ['Variable1', 'Variable2', 'Correlation']

# フィルタリングされた組み合わせに対して散布図を作成
#output_dir = '1st_scatter_plots'
#os.makedirs(output_dir, exist_ok=True)

for index, row in high_correlation_pairs.iterrows():
    variable1 = row['Variable1']
    variable2 = row['Variable2']
    correlation = row['Correlation']
    
    plt.figure(figsize=(8, 6))
    sns.scatterplot(x=data[variable1], y=data[variable2])
    plt.title(f'Scatter Plot: {variable1} vs {variable2}\nSpearman Correlation: {correlation:.2f}')
    plt.xlabel(variable1)
    plt.ylabel(variable2)
    
    # 散布図を保存
    #output_path = os.path.join(output_dir, f'scatter_plot_{variable1}_vs_{variable2}.png')
    #plt.savefig(output_path)
    #plt.close()

# 抽出された組み合わせと相関係数をCSVファイルに保存
high_correlation_pairs.to_csv('2nd_high_correlation_pairs.csv', index=False)

print("相関係数が0.4以上の組み合わせの情報と散布図が 'high_correlation_pairs.csv' および 'scatter_plots' ディレクトリに保存されました。")
# Out:
# C:\Users\Utsuk\AppData\Local\Temp\ipykernel_1428\3961845163.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(8, 6))
# 相関係数が0.4以上の組み合わせの情報と散布図が 'high_correlation_pairs.csv' および 'scatter_plots' ディレクトリに保存されました。

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# CSVファイルから指定の列を読み取り
columns_to_read = [
    'Kp_4', 'Ki_4', 'Kd_4', 'Ki/|Kp|_4', 'Kd/|Kp|_4',
    'Average number of shares purchased_4',
    'Average stock price at time of purchase_4',
    'Average stock price change rate at time of purchase_4',
    'Average number of shares sold_4',
    'Average stock price at time of sale_4',
    'Average stock price change rate at time of sale_4'
]

data = pd.read_csv(csv_path, usecols=columns_to_read)

# 変数名を短くする
short_column_names = [
    'Kp_4', 'Ki_4', 'Kd_4', 'Ki_abs-Kp_4', 'Kd_abs-Kp_4',
    'Ave_stock_purchased_4',
    'Ave_stock_price_at_purchase_4',
    'Ave_stock_price_change_at_purchase_4',
    'Ave_stock_sold_4',
    'Ave_stock_price_at_sale_4',
    'Ave_stock_price_change_at_sale_4'
]

data.columns = short_column_names

# スピアマンの順位相関係数を計算
correlation_matrix = data.corr(method='spearman')

# 相関係数が0.4以上かつ1でない組み合わせを抽出
high_correlation_pairs = correlation_matrix[((abs(correlation_matrix) >= 0.4) & (abs(correlation_matrix) < 1))].stack().reset_index()
high_correlation_pairs.columns = ['Variable1', 'Variable2', 'Correlation']

# 重複を削除
high_correlation_pairs = high_correlation_pairs[high_correlation_pairs['Variable1'] < high_correlation_pairs['Variable2']]

# フィルタリングされた組み合わせに対して散布図を作成
output_dir = 'NEW_4TH_scatter_plots'
os.makedirs(output_dir, exist_ok=True)

for index, row in high_correlation_pairs.iterrows():
    variable1 = row['Variable1']
    
    
    variable2 = row['Variable2']
    correlation = row['Correlation']
    
    plt.figure(figsize=(8, 6))
    sns.scatterplot(x=data[variable1], y=data[variable2])
    plt.title(f'Scatter Plot: {variable1} vs {variable2}\nSpearman Correlation: {correlation:.2f}')
    plt.xlabel(variable1)
    plt.ylabel(variable2)
    
    # 散布図を保存
    output_path = os.path.join(output_dir, f'4TH_scatter_plot_{variable1}_vs_{variable2}.png')
    plt.savefig(output_path)
    plt.close()

# 抽出された組み合わせと相関係数をCSVファイルに保存
high_correlation_pairs.to_csv('4TH_high_correlation_pairs.csv', index=False)

print("相関係数が0.4以上かつ1でない組み合わせの情報と散布図が '4TH_high_correlation_pairs.csv' および 'scatter_plots' ディレクトリに保存されました。")
# Out:
# 相関係数が0.4以上かつ1でない組み合わせの情報と散布図が '4TH_high_correlation_pairs.csv' および 'scatter_plots' ディレクトリに保存されました。

# %%
# CSVファイルのパスを指定
input_file_path = "1st_trend.csv"

# CSVファイルを読み込む
df = pd.read_csv(input_file_path)

# Kp_1列とKd-Ki_1列を選択
kp_1 = df['Kp_1']
kd_ki_1 = df['Kd-Ki_1']

# スピアマンの順位相関係数を計算
rho, _ = spearmanr(kp_1, kd_ki_1)

# 結果の表示
print(f"Spearmanの順位相関係数: {rho:.4f}")
# Out:
# Spearmanの順位相関係数: 0.2133

# %%
df = pd.read_csv(csv_path)

# Kd_４とAverage number of shares purchased_4の散布図
plt.scatter(df['Kd_4'], df['Average number of shares purchased_4'])
plt.title('Scatter Plot: Kd_4 and Average number of shares purchased_4')
plt.xlabel('Kd_4')
plt.ylabel('Average number of shares purchased_4')
plt.show()

# Kp_4とAve number of shares purchased_4の散布図
plt.scatter(df['Kd_4'], df['Average number of shares sold_4'])
plt.title('Scatter Plot: Kd_4 and Average number of shares sold_4')
plt.xlabel('Kd_4')
plt.ylabel('Ave number of shares sold_4')
plt.show()
